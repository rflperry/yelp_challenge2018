# %%
import networkx as nx
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import Series, DataFrame

# %matplotlib inline

import os

# %%
#Load Pickles
review1_df = pd.read_pickle('./review1_df.pkl')
business_df = pd.read_pickle('./business_df.pkl')
user_df = pd.read_pickle('./user_df.pkl')

# %%
list(business_df)
# Out:
# ['address',
#  'attributes',
#  'business_id',
#  'categories',
#  'city',
#  'hours',
#  'is_open',
#  'latitude',
#  'longitude',
#  'name',
#  'neighborhood',
#  'postal_code',
#  'review_count',
#  'stars',
#  'state']

# %%
list(user_df)
# Out:
# ['average_stars', 'friends', 'name', 'review_count', 'useful', 'user_id']

# %%
#Filter Businesses
business_df = business_df[business_df['categories'].str.contains('Restaurants|Food',na=False)]

# %%
#Businesses we care about
biz_df = business_df[business_df['city']=='Toronto']
biz_df = biz_df[biz_df['review_count'] > 5]

# %%
#Form Time Series
ts = {b:[] for b in biz_df['business_id']}
for row in review1_df.itertuples(index=True):
    if row.business_id in ts.keys():
        ts[row.business_id].append((row.date.year,row.date.month,row.stars))

# %%
for k in list(ts.keys()):
    if ts[k] == []:
        del ts[k]

# %%
#Category dictionary
cat = {}
for row in business_df.itertuples(index=True):
    i = row.business_id
    if i not in ts.keys():
        continue
    for c in row.categories.split(', '):
        if c not in cat.keys():
            cat[c] = [i]
        else:
            cat[c].append(i)

# %%
#Time series for number of reviews
def make_ts(tpls,time_series):
    min_yr = min(i for i,_,_ in tpls)
    organized = {}
    for y,m,s in tpls:
        key = (y-min_yr)*12 + m
        if key not in organized.keys():
            organized[key] = 0#[]
        organized[key] = organized[key] + 1#.append(s)
    for key in organized.keys():
        time_series[key-1] = organized[key]
    #for key in range(min(organized.keys()),max(organized.keys())+1):
    #    if key in organized.keys():
    #        time_series.append(organized[key])#np.mean(organized[key]))
    #    else:
    #        time_series.append(0)#time_series[-1])
    #time_series = np.array(time_series)
    #time_series = np.append(np.zeros(min(organized.keys()) - 1), time_series)
    return time_series

# %%
#Time series for number of reviews
def make_yearly_ts(tpls,nan):
    time_series = np.zeros(12)
    yrs_counted = {i:set() for i in range(0,12)}
    for y,m,s in tpls:
        if y == 2018: continue
        time_series[m-1] += 1
        yrs_counted[m-1].add(y)
    #return [time_series[i] / len(tpls) for i in range(0,12)]
    #rslt = [time_series[i] / max(len(yrs_counted[i]),1) for i in range(0,12)] #Corrects for divide by zero
    return time_series

# %%
#Makes the initial time series across all years
min_yr = 2018
max_dt = 0
for rev in ts.values():
    for yr,m,_ in rev:
        key = yr*12 + m
        if yr < min_yr:
            min_yr = yr
        if key > max_dt:
            max_dt = key
initial_ts = np.zeros(max_dt - min_yr*12)

# %%
time_series = {}
for key,val in ts.items():
    time_series[key] = make_yearly_ts(val, np.copy(initial_ts))

# %%
cat_ts = {k:np.zeros(12) for k in cat.keys()}
for key,bizs in cat.items():
    for biz in bizs:
        cat_ts[key] = cat_ts[key] + time_series[biz]
    cat_ts[key] = cat_ts[key]

# %%
cat_ts.keys()
# Out:
# dict_keys(['Food', 'Bakeries', 'Cajun/Creole', 'Southern', 'Restaurants', 'Coffee & Tea', 'Canadian (New)', 'Caribbean', 'Breakfast & Brunch', 'Nightlife', 'Wine Bars', 'Indian', 'Bars', 'Pubs', 'Salad', 'Chicken Wings', 'Sandwiches', 'Pizza', 'Mexican', 'Grocery', 'Latin American', 'Brewpubs', 'Gastropubs', 'Breweries', 'Specialty Food', 'Candy Stores', 'Chocolatiers & Shops', 'Desserts', 'Ethnic Food', 'Imported Food', 'Burgers', 'Food Delivery Services', 'Cafes', 'Chinese', 'Dim Sum', 'Japanese', 'Donuts', 'Vietnamese', 'Diners', 'Caterers', 'Event Planning & Services', 'Music Venues', 'Arts & Entertainment', 'Thai', 'Ice Cream & Frozen Yogurt', 'Fast Food', 'Sushi Bars', 'Poke', 'Asian Fusion', 'Juice Bars & Smoothies', 'Italian', 'Greek', 'Mediterranean', 'Middle Eastern', 'French', 'Cocktail Bars', 'Turkish', 'Convenience Stores', 'Tea Rooms', 'Seafood', 'Fondue', 'Korean', 'Food Stands', 'Delis', 'Health Markets', 'Organic Stores', 'Food Trucks', 'American (Traditional)', 'Lounges', 'Real Estate', 'Shared Office Spaces', 'Home Services', 'Venues & Event Spaces', 'Barbeque', 'Steakhouses', 'Argentine', 'Beer', 'Wine & Spirits', 'Poutineries', 'Butcher', 'Meat Shops', 'Jewelry', 'Arts & Crafts', 'Alternative Medicine', 'Shopping', 'Health & Medical', 'Active Life', 'Meditation Centers', 'Fitness & Instruction', 'Local Flavor', 'Food Court', 'Tapas/Small Plates', 'Tapas Bars', 'Vegetarian', 'Sports Bars', 'Brasseries', 'Portuguese', 'Vegan', 'Modern European', 'Tex-Mex', 'Hotels & Travel', 'Hotels', 'Fish & Chips', 'Bangladeshi', 'Department Stores', 'Fashion', 'Singaporean', 'Couriers & Delivery Services', 'Local Services', 'Bubble Tea', 'Coffee & Tea Supplies', 'Spanish', 'Fruits & Veggies', 'Gluten-Free', 'Falafel', 'Pakistani', 'International Grocery', 'American (New)', 'Comfort Food', 'Seafood Markets', 'Nutritionists', 'Cheese Shops', 'Custom Cakes', 'Venezuelan', 'Professional Services', 'Life Coach', 'Kebab', 'Ethiopian', 'Halal', 'Internet Cafes', 'Discount Store', "Men's Clothing", 'Buffets', 'Bagels', 'Soup', 'Persian/Iranian', 'Belgian', 'Himalayan/Nepalese', 'Books', 'Mags', 'Music & Video', 'Comic Books', 'Team Building Activities', 'Noodles', 'Taiwanese', 'Milkshake Bars', 'Hot Dogs', 'Chicken Shop', 'Hobby Shops', 'Soul Food', 'Waffles', 'Colombian', 'Do-It-Yourself Food', 'Tobacco Shops', 'Hookah Bars', 'Moroccan', 'Jazz & Blues', 'Street Vendors', 'Bistros', 'Pool Halls', 'Creperies', 'Wineries', 'Russian', 'Ramen', 'Delicatessen', 'Ukrainian', 'Polish', 'Wigs', 'Beer Bar', 'Kosher', 'Party & Event Planning', 'Patisserie/Cake Shop', 'Head Shops', 'Whiskey Bars', 'Hair Salons', 'Beauty & Spas', 'Hawaiian', 'Donairs', 'Coffee Roasteries', 'Playgrounds', 'Afghan', 'British', 'Smokehouse', 'African', 'Scandinavian', 'Brazilian', 'Lebanese', 'Sri Lankan', 'Mosques', 'Religious Organizations', 'Dance Clubs', 'Gay Bars', 'Pan Asian', 'Arabian', 'Personal Chefs', 'Farmers Market', 'Cideries', 'Performing Arts', 'Irish', 'Irish Pub', 'International', 'German', 'Austrian', 'Social Clubs', 'Filipino', 'Karaoke', 'Cheesesteaks', 'Peruvian', 'Gift Shops', 'Flowers & Gifts', 'Community Service/Non-Profit', 'South African', 'Ethical Grocery', 'Vitamins & Supplements', 'Live/Raw Food', 'Hot Pot', 'Herbs & Spices', 'Scottish', 'Malaysian', 'Festivals', 'Amusement Parks', 'Doctors', 'Naturopathic/Holistic', 'Wholesale Stores', 'Shaved Snow', 'Used', 'Vintage & Consignment', 'Arcades', 'Hungarian', 'Salvadoran', 'Wedding Planning', 'Education', 'Specialty Schools', 'Art Schools', 'Bookstores', 'Music & DVDs', 'Gelato', 'Dive Bars', 'Tabletop Games', 'Art Galleries', 'Hainan', 'Drugstores', 'Vinyl Records', 'Swimming Pools', 'Dinner Theater', 'Stadiums & Arenas', 'Cooking Schools', 'Comedy Clubs', 'Cuban', 'Cosmetics & Beauty Supply', 'Florists', 'Beer Gardens', 'Acai Bowls', 'Basque', 'Public Markets', 'Macarons', 'Cambodian', 'Indonesian', 'Cantonese', 'Hakka', 'Accessories', "Women's Clothing", 'Szechuan', 'Haitian', 'Per ...

# %%
plt.plot(cat_ts['Ramen'])

# %%
plt.figure(figsize=(10,3))
for biz in cat['Ramen']:
    plt.plot(time_series[biz])

# %%
plt.hist([sum(time_series[i]) for i in cat['Ramen']],bins=30)
# Out:
# (array([4., 1., 5., 2., 1., 0., 4., 2., 1., 5., 3., 2., 2., 2., 3., 1., 0.,
#         0., 1., 0., 0., 0., 3., 1., 0., 1., 0., 0., 0., 1.]),
#  array([ 1.        ,  2.48333333,  3.96666667,  5.45      ,  6.93333333,
#          8.41666667,  9.9       , 11.38333333, 12.86666667, 14.35      ,
#         15.83333333, 17.31666667, 18.8       , 20.28333333, 21.76666667,
#         23.25      , 24.73333333, 26.21666667, 27.7       , 29.18333333,
#         30.66666667, 32.15      , 33.63333333, 35.11666667, 36.6       ,
#         38.08333333, 39.56666667, 41.05      , 42.53333333, 44.01666667,
#         45.5       ]),
#  <a list of 30 Patch objects>)

# %%
G_ts = nx.Graph()
G_ts.add_nodes_from(time_series.keys())

# %%
import itertools
import warnings

# %%
for a,b in itertools.combinations(G_ts.nodes, 2):
    tsa,tsb = time_series[a],time_series[b]
    min_len = min(len(tsa),len(tsb))
    with warnings.catch_warnings():
        warnings.filterwarnings('error')
        try:
            coeff = np.corrcoef(tsa[:min_len],tsb[:min_len])[0,1]
        except:
            coeff = 0
    if coeff > 0.9:
        #plt.subplot(2,1,1)
        #plt.plot(time_series[a][:min_len])
        #plt.subplot(2,1,2)
        #plt.plot(time_series[b][:min_len])
        G_ts.add_edge(a,b,weight=float(coeff))

# %%
GCC = max(list(nx.connected_component_subgraphs(G_ts)),key=len)

# %%
GCC = nx.Graph()

# %%
for row in biz_df[biz_df['city']=='Toronto'].itertuples(index=True):
    GCC.add_node(row.business_id)

# %%
warnings.filterwarnings("ignore", category=PendingDeprecationWarning)

# %%
plt.figure(figsize=(20,20))
nx.draw_spring(GCC)

# %%
import os
os.environ['PROJ_LIB'] = r'C:\Users\Ronan Perry\Anaconda3\pkgs\proj4-5.1.0-hfa6e2cd_1\Library\share'
from mpl_toolkits.basemap import Basemap

# %%
lats,lons,names,sizes = [],[],[],[]
for biz in GCC.nodes:
    lookup = business_df[business_df['business_id'] == biz]
    names.append(lookup['name'])
    lons.append(float(lookup['longitude']))
    lats.append(float(lookup['latitude']))
    sizes.append(1)#GCC.degree[biz])

# %%
# How much to zoom from coordinates (in degrees)
zoom_scale = 3

# Setup the bounding box for the zoom and bounds of the map
bbox = [np.min(lats)-zoom_scale,np.max(lats)+zoom_scale,\
        np.min(lons)-zoom_scale,np.max(lons)+zoom_scale]

plt.figure(figsize=(20,20))
plt.title("Yelp Businesses separation from user")
# Define the projection, scale, the corners of the map, and the resolution.
m = Basemap(projection='merc',llcrnrlat=bbox[0],urcrnrlat=bbox[1],\
            llcrnrlon=bbox[2],urcrnrlon=bbox[3],lat_ts=10)

# Draw coastlines and fill continents and water with color
m.drawcoastlines()
m.fillcontinents(color='#CCCCCC',lake_color='lightblue')

# draw parallels, meridians, and color boundaries
m.drawparallels(np.arange(bbox[0],bbox[1],(bbox[1]-bbox[0])/5),labels=[1,0,0,0])
m.drawmeridians(np.arange(bbox[2],bbox[3],(bbox[3]-bbox[2])/5),labels=[0,0,0,1],rotation=15)
m.drawmapboundary(fill_color='lightblue')

# plot elevations with different colors using the numpy interpolation mapping tool
# the range [50,200] can be changed to create different colors and ranges
for ii in range(0,len(names)):
    x,y = m(lons[ii],lats[ii])
    plt.plot(x,y,3,marker='o',color='red')
    
for e1,e2 in GCC.edges:
    x1,y1 = m(float(business_df[business_df['business_id']==e1]['longitude']),float(business_df[business_df['business_id']==e1]['latitude']))
    x2,y2 = m(float(business_df[business_df['business_id']==e2]['longitude']),float(business_df[business_df['business_id']==e2]['latitude']))
    plt.plot([x1, x2],[y1, y2],color='black')

# %%
cliques = list(nx.find_cliques(G_ts))

# %%
for a,b in GCC.edges:
    print(a,b)
    break
# Out:
# glkEaoxbewiSMBiXs945JA vHz2RLtfUMVRPFmd7VBEHA
